# %% [markdown]
# #  Capstone Project 2: Stock price forecasting
# # Section 2: Data wrangling

# %% [markdown]
# In this notebook we focus on the data wrangling part of the project. We will collect data about historical stock prices and company earnings using Yahoo Finance and Alpha Vantage. The aim is to create a dataframe containing all the relevant information to train our models for stock price forecasting in future steps. We will focus on two stocks: Coca-Cola, a stock with a long history of solid growth, and Tesla, a newer and more volatile one.

# %% [markdown]
# ## 1. Coca-Cola stock

# %%
import os
import sys
import requests
import json
import numpy as np
import pandas as pd

# %% [markdown]
# ### Data collection

# %% [markdown]
# We shall import the historical stock price data from Yahoo Finance. Let's start with the Coca-Cola stock, whose ticker is `KO`. Obviously the start date of the collected data will vary for the different stocks. Regarding the end date, we shall fix it as 31st December 2022.

# %%
import yfinance as yf

# Define the ticker symbol and end date
ticker = "KO"
end_date = "2022-12-31"

# Fetch the historical data using yfinance with start=None
data = yf.download(ticker, start=None, end=end_date)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
# Make sure we have a dataframe type
type(data)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Now we shall print out the head of our dataset `data`:

# %%
# Print out the head of the dataframe
data.head()
# Out:
#                 Open      High       Low     Close  Adj Close   Volume
# Date
# 1962-01-02  0.263021  0.270182  0.263021  0.263021   0.048913   806400
# 1962-01-03  0.259115  0.259115  0.253255  0.257161   0.047823  1574400
# 1962-01-04  0.257813  0.261068  0.257813  0.259115   0.048187   844800
# 1962-01-05  0.259115  0.262370  0.252604  0.253255   0.047097  1420800
# 1962-01-08  0.251302  0.251302  0.245768  0.250651   0.046613  2035200

# %% [markdown]
# Let's check for missing values and NaN values:

# %%
# Check for missing values in the DataFrame
missing_values = data.isnull().sum()

# Print the missing values count
print(missing_values)
# Out:
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
# Check for NaN values in the DataFrame
nan_values = data.isna().sum()

# Print the NaN values count
print(nan_values)
# Out:
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %% [markdown]
# We have no missing or NaN values in this original dataset for stock prices. However, in future steps we will find NaN values for certain rows when computing financial indicators, and these will need to be dropped.

# %% [markdown]
# With this information about stock prices we can compute financial indicators, which will be used as features. However, we would like
# to have additional features that are not directly related to the stock price, such as the earnings per share (EPS), which enables us to compute the P/E ratio --a commonly used metric to value a publicly traded company. Here we shall
# import this information from the Alpha Vantage API.

# %% [markdown]
# In order to avoid posting publicly our API key, we shall store it in a `.env` file and use the `python-dotenv` package to load the key into environment variables.

# %%
from dotenv import load_dotenv
import os

load_dotenv()

API_KEY = os.getenv('API_KEY')

# %%
# Obtaining earnings per share (EPS)

BASE_URL = "https://www.alphavantage.co/query?"

def earnings_history_api(api_key, symbol):
    assert symbol is not None
    symbol = symbol.strip().upper()

    url = f"{BASE_URL}function=EARNINGS&symbol={symbol}&apikey={api_key}"

    response = requests.get(url)
    data = response.json()

    if 'quarterlyEarnings' in data:
        earnings_data = data['quarterlyEarnings']
        df = pd.DataFrame(earnings_data)
        return df
    else:
        print("No earnings data found for the specified symbol.")
        return None

df_earnings = earnings_history_api(API_KEY, "KO")

# Print dataframe with EPS
df_earnings
# Out:
#     fiscalDateEnding reportedDate reportedEPS estimatedEPS surprise  \
# 0         2023-03-31   2023-04-24        0.68         0.65     0.03
# 1         2022-12-31   2023-02-14        0.45         0.45        0
# 2         2022-09-30   2022-10-25        0.69         0.64     0.05
# 3         2022-06-30   2022-07-26         0.7         0.67     0.03
# 4         2022-03-31   2022-04-25        0.64         0.58     0.06
# ..               ...          ...         ...          ...      ...
# 104       1997-03-31   1997-04-14         0.2          0.2        0
# 105       1996-12-31   1997-01-31        0.16         0.16        0
# 106       1996-09-30   1996-10-15         0.2         0.19     0.01
# 107       1996-06-30   1996-07-15        0.21         0.21        0
# 108       1996-03-31   1996-04-17        0.14         0.14        0
#
#     surprisePercentage
# 0               4.6154
# 1                    0
# 2               7.8125
# 3               4.4776
# 4              10.3448
# ..                 ...
# 104                  0
# 105                  0
# 106             5.2632
# 107                  0
# 108                  0
#
# [109 rows x 6 columns]

# %% [markdown]
# We see that the first row in this dataframe dates from 1996-03-01, which is way more recent that the first data within the historical stock prices dataframe. Still, the EPS dataframe provides us with 26 years of data, which in combination with the stock prices data restricted to this period should be sufficient to effectively train our models.

# %% [markdown]
# In the dataframes of Alpha Vantage missing values appear as "None". We have to check that there are no None values in `df_earnings`:

# %%
(df_earnings == 'None').sum().sum()
# Out:
# 0

# %% [markdown]
# ###  Data organization and data cleaning

# %% [markdown]
# We now would like to incorporate the `reportedEPS` column in our dataframe for stock prices `data`, in such a way that every row is assigned the reported EPS that corresponds to the row's date. In order to do this, first we note that the data type of the `reportedDate` column is different from the data type of the index in our main dataframe: the former is an Object type whereas the latter is a datetime64 type.

# %%
print(df_earnings['reportedDate'].dtype)
# Out:
# object

# %%
print(data.index.dtype)
# Out:
# datetime64[ns]

# %% [markdown]
# So first we need to convert the data type of the `reportedDate` column to a datetime64 type.

# %%
# Convert the reportedDate column to a datetime64 type
df_earnings['reportedDate'] = pd.to_datetime(df_earnings['reportedDate']) 

# Check data type
print(df_earnings['reportedDate'].dtype)
# Out:
# datetime64[ns]

# %% [markdown]
# Then we promote the `reportedDate` column to being the index:

# %%
# Set the `reportedDate' column as the index
df_earnings = df_earnings.set_index('reportedDate')

# Print the dataframe and check
df_earnings.head()
# Out:
#              fiscalDateEnding reportedEPS estimatedEPS surprise  \
# reportedDate
# 2023-04-24         2023-03-31        0.68         0.65     0.03
# 2023-02-14         2022-12-31        0.45         0.45        0
# 2022-10-25         2022-09-30        0.69         0.64     0.05
# 2022-07-26         2022-06-30         0.7         0.67     0.03
# 2022-04-25         2022-03-31        0.64         0.58     0.06
#
#              surprisePercentage
# reportedDate
# 2023-04-24               4.6154
# 2023-02-14                    0
# 2022-10-25               7.8125
# 2022-07-26               4.4776
# 2022-04-25              10.3448

# %% [markdown]
# Let's sort the dataframe in ascending order:

# %%
df_earnings.sort_index(ascending=True, inplace=True)

# %%
df_earnings.head()
# Out:
#              fiscalDateEnding reportedEPS estimatedEPS surprise  \
# reportedDate
# 1996-04-17         1996-03-31        0.14         0.14        0
# 1996-07-15         1996-06-30        0.21         0.21        0
# 1996-10-15         1996-09-30         0.2         0.19     0.01
# 1997-01-31         1996-12-31        0.16         0.16        0
# 1997-04-14         1997-03-31         0.2          0.2        0
#
#              surprisePercentage
# reportedDate
# 1996-04-17                    0
# 1996-07-15                    0
# 1996-10-15               5.2632
# 1997-01-31                    0
# 1997-04-14                    0

# %% [markdown]
# We are only interested in adding the `reportedEPS` column, so we shall drop the others.

# %%
df_earnings.drop(["fiscalDateEnding", "estimatedEPS", "surprise", "surprisePercentage"], axis=1, inplace=True)

# %% [markdown]
# Let's also change the name of `reportedEPS` column to `Reported EPS`:

# %%
df_earnings.rename(columns={'reportedEPS': 'Reported EPS'}, inplace=True)

# %% [markdown]
# Finally we merge the two dataframes on their index and forward fill the missing values in the `Reported EPS` column

# %%
# Merge 'data' and 'df_earnings' based on their index
merged_df = data.join(df_earnings, how="left")

# Forward fill the missing values in the "Reported EPS" column
merged_df["Reported EPS"].fillna(method="ffill", inplace=True)

# %% [markdown]
# Let's have a look at the head of our merged dataframe:

# %%
merged_df.head()
# Out:
#                 Open      High       Low     Close  Adj Close   Volume  \
# Date
# 1962-01-02  0.263021  0.270182  0.263021  0.263021   0.048913   806400
# 1962-01-03  0.259115  0.259115  0.253255  0.257161   0.047823  1574400
# 1962-01-04  0.257813  0.261068  0.257813  0.259115   0.048187   844800
# 1962-01-05  0.259115  0.262370  0.252604  0.253255   0.047097  1420800
# 1962-01-08  0.251302  0.251302  0.245768  0.250651   0.046613  2035200
#
#            Reported EPS
# Date
# 1962-01-02          NaN
# 1962-01-03          NaN
# 1962-01-04          NaN
# 1962-01-05          NaN
# 1962-01-08          NaN

# %% [markdown]
# As we mentioned earlier, the dataframe containing information about EPS only has entries from 1996-04-07, so we will drop the rows up to that point. This will yield a dataframe with sufficent information to fit our models reasonably well.

# %%
# Drop rows with NaN values
df = merged_df.dropna()

# Print the final form of our dataframe
df
# Out:
#                  Open       High        Low      Close  Adj Close    Volume  \
# Date
# 1996-04-17  20.281250  20.281250  19.843750  20.031250  10.141943   8906000
# 1996-04-18  20.031250  20.156250  19.843750  19.875000  10.062835   9608000
# 1996-04-19  19.875000  20.062500  19.562500  19.687500   9.967903  13010400
# 1996-04-22  19.875000  20.187500  19.875000  20.156250  10.205235   7160800
# 1996-04-23  20.156250  20.281250  20.062500  20.250000  10.252699   6218800
# ...               ...        ...        ...        ...        ...       ...
# 2022-12-23  63.500000  63.869999  63.200001  63.820000  62.855492   6463300
# 2022-12-27  63.930000  64.290001  63.709999  64.209999  63.239597   7320700
# 2022-12-28  64.459999  64.650002  63.490002  63.570000  62.609272   7159400
# 2022-12-29  63.799999  64.150002  63.700001  63.950001  62.983532   7169300
# 2022-12-30  63.919998  63.919998  63.169998  63.610001  62.648666   7650200
#
#            Reported EPS
# Date
# 1996-04-17         0.14
# 1996-04-18         0.14
# 1996-04-19         0.14
# 1996-04-22         0.14
# 1996-04-23         0.14
# ...                 ...
# 2022-12-23         0.69
# 2022-12-27         0.69
# 2022-12-28         0.69
# 2022-12-29         0.69
# 2022-12-30         0.69
#
# [6724 rows x 7 columns]

# %% [markdown]
# Let's now check that the `Reported EPS` column has been filled correctly when the values are updated. For instance, let's print the transition from 2022-07-25 to 2022-07-26:

# %%
# Print our final dataframe on the selected transition date
df.tail(112)
# Out:
#                  Open       High        Low      Close  Adj Close    Volume  \
# Date
# 2022-07-25  61.549999  62.299999  61.310001  62.189999  60.378578  14941700
# 2022-07-26  62.750000  63.799999  62.529999  63.209999  61.368870  20118000
# 2022-07-27  62.880001  63.189999  61.790001  63.009998  61.174698  12142900
# 2022-07-28  62.919998  64.250000  62.889999  64.059998  62.194111  10837000
# 2022-07-29  63.709999  64.290001  63.630001  64.169998  62.300907  13734200
# ...               ...        ...        ...        ...        ...       ...
# 2022-12-23  63.500000  63.869999  63.200001  63.820000  62.855492   6463300
# 2022-12-27  63.930000  64.290001  63.709999  64.209999  63.239597   7320700
# 2022-12-28  64.459999  64.650002  63.490002  63.570000  62.609272   7159400
# 2022-12-29  63.799999  64.150002  63.700001  63.950001  62.983532   7169300
# 2022-12-30  63.919998  63.919998  63.169998  63.610001  62.648666   7650200
#
#            Reported EPS
# Date
# 2022-07-25         0.64
# 2022-07-26          0.7
# 2022-07-27          0.7
# 2022-07-28          0.7
# 2022-07-29          0.7
# ...                 ...
# 2022-12-23         0.69
# 2022-12-27         0.69
# 2022-12-28         0.69
# 2022-12-29         0.69
# 2022-12-30         0.69
#
# [112 rows x 7 columns]

# %% [markdown]
# We see that the `Reported EPS` column is correctly updated on the correspoding date accoridng to the information in the dataframe `df_earnings`.

# %% [markdown]
# ### 2. Tesla stock

# %% [markdown]
# We shall repeat the same steps we took in the previous section but focusing this time on the TSLA ticker.

# %% [markdown]
# ### Data collection

# %%
data2 = yf.download('TSLA', start=None, end=end_date)
data2
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-06-29    1.266667    1.666667    1.169333    1.592667    1.592667
# 2010-06-30    1.719333    2.028000    1.553333    1.588667    1.588667
# 2010-07-01    1.666667    1.728000    1.351333    1.464000    1.464000
# 2010-07-02    1.533333    1.540000    1.247333    1.280000    1.280000
# 2010-07-06    1.333333    1.333333    1.055333    1.074000    1.074000
# ...                ...         ...         ...         ...         ...
# 2022-12-23  126.370003  128.619995  121.019997  123.150002  123.150002
# 2022-12-27  117.500000  119.669998  108.760002  109.099998  109.099998
# 2022-12-28  110.349998  116.269997  108.239998  112.709999  112.709999
# 2022-12-29  120.389999  123.570000  117.500000  121.820000  121.820000
# 2022-12-30  119.949997  124.480003  119.750000  123.180000  123.180000
#
#                Volume
# Date
# 2010-06-29  281494500
# 2010-06-30  257806500
# 2010-07-01  123282000
# 2010-07-02   77097000
# 2010-07-06  103003500
# ...               ...
# 2022-12-23  166989700
# 2022-12-27  208643400
# 2022-12-28  221070500
# 2022-12-29  221923300
# 2022-12-30  157777300
#
# [3150 rows x 6 columns]

# %%
# Check for missing values in the DataFrame
missing_values = data2.isnull().sum()

# Print the missing values count
print(missing_values)
# Out:
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
# Check for NaN values in the DataFrame
nan_values = data2.isna().sum()

# Print the NaN values count
print(nan_values)
# Out:
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
df_earnings2 = earnings_history_api(API_KEY, "TSLA")
df_earnings2
# Out:
#    fiscalDateEnding reportedDate reportedEPS estimatedEPS surprise  \
# 0        2023-03-31   2023-04-19        0.85         0.85        0
# 1        2022-12-31   2023-01-25        1.19         1.13     0.06
# 2        2022-09-30   2022-10-19        1.05         0.99     0.06
# 3        2022-06-30   2022-07-20        0.76          0.6     0.16
# 4        2022-03-31   2022-04-20        1.07         0.75     0.32
# 5        2021-12-31   2022-01-26        0.85         0.79     0.06
# 6        2021-09-30   2021-10-20        0.62         0.53     0.09
# 7        2021-06-30   2021-07-26        0.48         0.33     0.15
# 8        2021-03-31   2021-04-26        0.31         0.26     0.05
# 9        2020-12-31   2021-01-27        0.27         0.34    -0.07
# 10       2020-09-30   2020-10-21        0.25         0.19     0.06
# 11       2020-06-30   2020-07-22        0.15        -0.01     0.16
# 12       2020-03-31   2020-04-29        0.08        -0.02      0.1
# 13       2019-12-31   2020-01-29        0.14         0.11     0.03
# 14       2019-09-30   2019-10-23        0.12        -0.03     0.15
# 15       2019-06-30   2019-07-24       -0.07        -0.02    -0.05
# 16       2019-03-31   2019-04-24       -0.12        -0.05    -0.07
# 17       2018-12-31   2019-01-30        0.13         0.08     0.05
# 18       2018-09-30   2018-10-24        0.19         0.03     0.16
# 19       2018-06-30   2018-08-01       -0.16         -0.2     0.04
# 20       2018-03-31   2018-05-02       -0.22        -0.24     0.02
# 21       2017-12-31   2018-02-07        -0.2        -0.21     0.01
# 22       2017-09-30   2017-11-01       -0.19        -0.15    -0.04
# 23       2017-06-30   2017-08-02       -0.09        -0.12     0.03
# 24       2017-03-31   2017-05-03       -0.09        -0.09        0
# 25       2016-12-31   2017-02-22       -0.14        -0.21     0.07
# 26       2016-09-30   2016-10-26        0.14        -0.08     0.22
# 27       2016-06-30   2016-08-03       -0.07        -0.04    -0.03
# 28       2016-03-31   2016-05-04       -0.04        -0.05     0.01
# 29       2015-12-31   2016-02-10       -0.87          0.1    -0.97
# 30       2015-09-30   2015-11-03       -0.04        -0.04        0
# 31       2015-06-30   2015-08-05       -0.03         -0.6     0.57
# 32       2015-03-31   2015-05-06       -0.36         -0.5     0.14
# 33       2014-12-31   2015-02-11       -0.01         0.02    -0.03
# 34       2014-09-30   2014-11-05        0.02        -0.01     0.03
# 35       2014-06-30   2014-07-31        0.01         0.04    -0.03
# 36       2014-03-31   2014-05-07        0.01          0.1    -0.09
# 37       2013-12-31   2014-02-19        0.02         0.01     0.01
# 38       2013-09-30   2013-11-05        0.01         0.01        0
# 39       2013-06-30   2013-08-07        0.01        -0.01     0.02
# 40       2013-03-31   2013-05-08        0.01         0.04    -0.03
# 41       2012-12-31   2013-02-20       -0.04        -0.04        0
# 42       2012-09-30   2012-11-05       -0.06        -0.06        0
# 43       2012-06-30   2012-07-25       -0.06        -0.06        0
# 44       2012-03-31   2012-05-09       -0.05        -0.05        0
# 45       2011-12-31   2012-02-15       -0.05        -0.04    -0.01
# 46       2011-09-30   2011-11-02       -0.04        -0.04        0
# 47       2011-06-30   2011-08-03       -0.04        -0.03    -0.01
# 48       2011-03-31   2011-05-04       -0.03        -0.03        0
# 49       2010-12-31   2011-02-15       -0.03        -0.03        0
# 50       2010-09-30   2010-11-09       -0.02        -0.03     0.01
# 51       2010-06-30   2010-08-05     -0.0271         None     None
#
#    surprisePercentage
# 0                   0
# 1              5.3097
# 2              6.0606
# 3             26.6667
# 4             42.6667
# 5              7.5949
# 6             16.9811
# 7             45.4545
# 8             19.2308
# 9            -20.5882
# 10            31.5789
# 11               1600
# 12                500
# 13            27.2727
# 14                500
# 15               -250
# 16               -140
# 17               62.5
# 18           533.3333
# 19                 20
# 20             8.3333
# 21             4.7619
# 22           -26.6667
# 23                 25
# 24                  0
# 25            33.3333
# 26                275
# 27                -75
# 28                 20
# 29               -970
# 30                  0
# 31                 95
# 32                 28
# 33               -150
# 34                300
# 35                -75
# 36                -90
# 37                100
# 38                  0
# 39                200
# 40                -75
# 41                  0
# 42                  0
# 43                  0
# 44                  0
# 45                -25
# 46                  0
# 47           -33.3333
# 48                  0
# 49                  0
# 50            33.3333
# 51               None

# %% [markdown]
# Now we check for None values in `df_earnings2`. We see that there are 3 entries with a `None` value:

# %%
# Check for missing values in 'df_earnings2'
(df_earnings2 == 'None').sum().sum()
# Out:
# 3

# %% [markdown]
# However, these are the first entries for `estimatedEPS`, `surprise` and `surprisePErcentage`, which obviously must be undefined as there is no possibility of prior estimation. In any case, these `None` values do not affect our analysis, as we are just picking the `reportedEPS` column.

# %% [markdown]
# ### Data organization and cleaning

# %% [markdown]
# Let's incorporate the `reportedEPS` column into the dataframe `data2` containing stock price data. We follow the same steps as in the previous case.

# %%
# Convert the reportedDate column to a datetime64 type
df_earnings2['reportedDate'] = pd.to_datetime(df_earnings2['reportedDate']) 

# Check data type
print(df_earnings2['reportedDate'].dtype)
# Out:
# datetime64[ns]

# %%
# Set the `reportedDate' column as the index
df_earnings2 = df_earnings2.set_index('reportedDate')

# Sort in ascending order
df_earnings2.sort_index(ascending=True, inplace=True)

# Print the dataframe and check
df_earnings2.head()
# Out:
#              fiscalDateEnding reportedEPS estimatedEPS surprise  \
# reportedDate
# 2010-08-05         2010-06-30     -0.0271         None     None
# 2010-11-09         2010-09-30       -0.02        -0.03     0.01
# 2011-02-15         2010-12-31       -0.03        -0.03        0
# 2011-05-04         2011-03-31       -0.03        -0.03        0
# 2011-08-03         2011-06-30       -0.04        -0.03    -0.01
#
#              surprisePercentage
# reportedDate
# 2010-08-05                 None
# 2010-11-09              33.3333
# 2011-02-15                    0
# 2011-05-04                    0
# 2011-08-03             -33.3333

# %%
# Drop columns different from "reportedEPS" and rename to "Reported EPS"
df_earnings2.drop(["fiscalDateEnding", "estimatedEPS", "surprise", "surprisePercentage"], axis=1, inplace=True)
df_earnings2.rename(columns={'reportedEPS': 'Reported EPS'}, inplace=True)

# %%
# Merge 'data' and 'df_earnings' based on their index
merged_df2 = data2.join(df_earnings2, how="left")

# Forward fill the missing values in the "Reported EPS" column
merged_df2["Reported EPS"].fillna(method="ffill", inplace=True)

# %%
merged_df2.head()
# Out:
#                 Open      High       Low     Close  Adj Close     Volume  \
# Date
# 2010-06-29  1.266667  1.666667  1.169333  1.592667   1.592667  281494500
# 2010-06-30  1.719333  2.028000  1.553333  1.588667   1.588667  257806500
# 2010-07-01  1.666667  1.728000  1.351333  1.464000   1.464000  123282000
# 2010-07-02  1.533333  1.540000  1.247333  1.280000   1.280000   77097000
# 2010-07-06  1.333333  1.333333  1.055333  1.074000   1.074000  103003500
#
#            Reported EPS
# Date
# 2010-06-29          NaN
# 2010-06-30          NaN
# 2010-07-01          NaN
# 2010-07-02          NaN
# 2010-07-06          NaN

# %% [markdown]
# We observe that the first entries of `merged_df2` have NaN values for `Reported EPS`, as the first reported EPS happened after the stock became publicly traded. So we will drop these rows.

# %%
# Drop rows with NaN values
df2 = merged_df2.dropna()

# Print the final form of our dataframe
df2
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-08-05    1.436000    1.436667    1.336667    1.363333    1.363333
# 2010-08-06    1.340000    1.344000    1.301333    1.306000    1.306000
# 2010-08-09    1.326667    1.332000    1.296667    1.306667    1.306667
# 2010-08-10    1.310000    1.310000    1.254667    1.268667    1.268667
# 2010-08-11    1.246000    1.258667    1.190000    1.193333    1.193333
# ...                ...         ...         ...         ...         ...
# 2022-12-23  126.370003  128.619995  121.019997  123.150002  123.150002
# 2022-12-27  117.500000  119.669998  108.760002  109.099998  109.099998
# 2022-12-28  110.349998  116.269997  108.239998  112.709999  112.709999
# 2022-12-29  120.389999  123.570000  117.500000  121.820000  121.820000
# 2022-12-30  119.949997  124.480003  119.750000  123.180000  123.180000
#
#                Volume Reported EPS
# Date
# 2010-08-05   11943000      -0.0271
# 2010-08-06   11128500      -0.0271
# 2010-08-09   12190500      -0.0271
# 2010-08-10   19219500      -0.0271
# 2010-08-11   11964000      -0.0271
# ...               ...          ...
# 2022-12-23  166989700         1.05
# 2022-12-27  208643400         1.05
# 2022-12-28  221070500         1.05
# 2022-12-29  221923300         1.05
# 2022-12-30  157777300         1.05
#
# [3124 rows x 7 columns]
